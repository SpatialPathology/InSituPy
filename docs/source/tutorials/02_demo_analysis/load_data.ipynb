# %%
from insitupy import InSituData

# %%
xd = InSituData.read(r"C:\Users\ge37voy\.cache\InSituPy\out\archive\demo_insitupy_project")

# %%
xd.load_all()

# %%
import scanpy as sc

# %%
sc.pl.umap(adata=xd.cells.matrix, color="cell_type_dc_sub")

# %%
sc.__version__
# Out:
# '1.11.1'
